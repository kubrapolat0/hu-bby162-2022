# %% [markdown]
# <a href="https://colab.research.google.com/github/kubrapolat0/hu-bby162-2022/blob/main/Proje03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def testFon():
  testTekrar = True
  print("Teste Hoşgeldin :)") 
  print("Cevabınızı evet ya da hayır olarak giriniz!!!")
  print("Her bir soru 20 puandır başarılar:) ")
  sorular = ["Kedilerin 3 bacağı mı vardır?" ,"Su 100 derecede mi kaynar?" , "Tavukların 4 bacağı mı vardır?" , "Python programlama dili midir?"  , "Normandiya çıkartması 1944'te mi yaşanmıştır?"]
  cevaplar = ["hayır" , "evet"]
  dogru = 0
  yanlis = 0
  puan = 0 
  print("1.soru: " +sorular[0])
  cevap = input ("Cevabınızı giriniz: ")
  if cevap == cevaplar[0] :
    puan +=20
    dogru +=1
    print("Tebrikler, doğru bildiniz!") 
  else :
    yanlis +=1
    print("Yanlış cevap!")
  print("Doğru sayınız: " + str(dogru))
  print("Yanlış sayınız: " +str(yanlis))
  print("Toplam puanınız: " +str(puan))
  print("2.soru: " +sorular[1])
  cevap = input("Cevabınızı giriniz: ")
  if cevap == cevaplar[1] :
    puan +=20
    dogru +=1
    print("Tebrikler, doğru bildiniz!") 
  else :
    yanlis +=1
    print("Yanlış cevap!")
  print("Doğru sayınız: " + str(dogru))
  print("Yanlış sayınız: " +str(yanlis))
  print("Toplam puanınız: " +str(puan))
  print("3.soru: "+sorular[2])
  cevap = input("Cevabınızı giriniz: ")
  if cevap == cevaplar[0] :
    puan +=20
    dogru +=1
    print("Tebrikler, doğru bildiniz!") 
  else:
    yanlis +=1
    print("Yanlış cevap!")
  print("Doğru sayınız: " + str(dogru))
  print("Yanlış sayınız: " +str(yanlis))
  print("Toplam puanınız: " +str(puan))
  print("4.soru: "+sorular[3])
  cevap = input("Cevabınızı giriniz: ")
  if cevap == cevaplar[1] :
    puan +=20
    dogru +=1
    print("Tebrikler, doğru bildiniz!") 
  else:
    yanlis +=1
    print("Yanlış cevap!")
  print("Doğru sayınız: " + str(dogru))
  print("Yanlış sayınız: " +str(yanlis))
  print("Toplam puanınız: " +str(puan))
  print("5.soru: "+sorular[4])
  cevap = input("Cevabınızı giriniz: ")
  if cevap == cevaplar[1] :
    puan +=20
    dogru +=1
    print("Tebrikler, doğru bildiniz!") 
  else:
    yanlis +=1
    print("Yanlış cevap!")
    print("Toplam doğru sayınız: " +str(dogru))
    print("toplam yanlış sayınız: " +str(yanlis))
    print("Toplam puanınız: " +str(puan))
  if puan >= 60 :
    print("Tebrikler, testten geçtiniz!")
  else:
    print("Maalesef, testten kaldınız!")
    tekrar = input("Teste tekrardan başlamak ister misin? evet/hayır ")
    if tekrar == 'evet':
      testFon()
    else:
      print("Program Sonlandırıldı.")

testFon() # Fonksiyon Çağrıldı
# Out:
# Teste Hoşgeldin :)
# Cevabınızı evet ya da hayır olarak giriniz!!!
# Her bir soru 20 puandır başarılar:)
# 1.soru: Kedilerin 3 bacağı mı vardır?
# Cevabınızı giriniz: evet
# Yanlış cevap!
# Doğru sayınız: 0
# Yanlış sayınız: 1
# Toplam puanınız: 0
# 2.soru: Su 100 derecede mi kaynar?
# Cevabınızı giriniz: hayır
# Yanlış cevap!
# Doğru sayınız: 0
# Yanlış sayınız: 2
# Toplam puanınız: 0
# 3.soru: Tavukların 4 bacağı mı vardır?
# Cevabınızı giriniz: evet
# Yanlış cevap!
# Doğru sayınız: 0
# Yanlış sayınız: 3
# Toplam puanınız: 0
# 4.soru: Python programlama dili midir?
# Cevabınızı giriniz: evet
# Tebrikler, doğru bildiniz!
# Doğru sayınız: 1
# Yanlış sayınız: 3
# Toplam puanınız: 20
# 5.soru: Normandiya çıkartması 1944'te mi yaşanmıştır?
# Cevabınızı giriniz: evet
# Tebrikler, doğru bildiniz!
# Maalesef, testten kaldınız!
# Teste tekrardan başlamak ister misin? evet/hayır evet
# Teste Hoşgeldin :)
# Cevabınızı evet ya da hayır olarak giriniz!!!
# Her bir soru 20 puandır başarılar:)
# 1.soru: Kedilerin 3 bacağı mı vardır?
