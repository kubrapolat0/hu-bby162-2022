# %% [markdown]
# <a href="https://colab.research.google.com/github/kubrapolat0/hu-bby162-2022/blob/main/proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint

def oyun():
 from random import randint
basitKelimeler = ["ağaç","böcek","deniz","bulut"]
ortaKelimeler = ["elektrik","panjur","karanlık","cumartesi"]
ileriKelimeler = ["floresan","biyografi","fotoğraf","resepsiyon"]
print("ADAM ASMACA OYUNUNA HOŞGELDİNİZ!!!")
seviye = print("Seviyeler: 1-basit 2-orta 3-ileri ")
seviyeSec =input("Lütfen oynamak istediğiniz seviyenin numarasını yazınız: ")
oyunSec = True
while oyunSec:
  if seviyeSec == "1":
   print("Basit seviye oyunu başlıyor. Başarılar!")
   oyunSec = False
  elif seviyeSec == "2":
    print("Orta seviye oyunu başlıyor. Başarılar!")
    oyunSec = False
  elif seviyeSec == "3":
    print("İleri seviye oyunu başlıyor. Başarılar!")
    oyunSec = False
#basit seviye
def oyna(can):
  seviye1 = basitKelimeler
  sayı=len(seviye1)
  sec = randint(0,sayı-1)
  seckelime = basitKelimeler[sec]
  dizilen=[]
  for diz in basitKelimeler[sec]:
    dizilen.append("_")
    print(dizilen)
  while can >0:
    girilenler = input("Lütfen bir harf giriniz!: ")
    kontrol = girilenler in seckelime
    if kontrol == False:
      can-=1
    i = 0
    for kontrolEt in seckelime:
      if seckelime[i] == girilenler:
        dizilen[i] == girilenler
      i +=1
    print(dizilen)
    print("kalan can: " +str(can))
#orta seviye
def oyna(can):
  seviye2 = ortaKelimeler
  sayı=len(seviye2)
  sec = randint(0,sayı-1)
  seckelime = ortaKelimeler[sec]
  dizilen=[]
  for diz in ortaKelimeler[sec]:
    dizilen.append("_")
    print(dizilen)
  while can >0:
    girilenler = input("Lütfen bir harf giriniz!: ")
    kontrol = girilenler in seckelime
    if kontrol == False:
      can-=1
    i = 0
    for kontrolEt in seckelime:
      if seckelime[i] == girilenler:
        dizilen[i] == girilenler
      i +=1
    print(dizilen)
    print("kalan can: " +str(can))
#ileri seviye
def oyna(can):
  seviye3 = ileriKelimeler
  sayı=len(seviye3)
  sec = randint(0,sayı-1)
  seckelime = ileriKelimeler[sec]
  dizilen=[]
  for diz in ileriKelimeler[sec]:
    dizilen.append("_")
    print(dizilen)
  while can >0:
    girilenler = input("Lütfen bir harf giriniz!: ")
    kontrol = girilenler in seckelime
    if kontrol == False:
      can-=1
    i = 0
    for kontrolEt in seckelime:
      if seckelime[i] == girilenler:
        dizilen[i] == girilenler
      i +=1
    print(dizilen)
    print("kalan can: " +str(can))
def seviyeler():
  print("Seviye giriniz! 1-2-3")
  x = input("Seviye: ")
  if x == "1":
    oyna(10)
  elif x == "2":
    oyna(5)
  elif x == "3":
    oyna(3)
  else:
    print("Lütfen bir seviye giriniz!")


seviyeler()
